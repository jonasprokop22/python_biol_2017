# %%
import pandas as pd

# %%
mess_table = pd.read_excel ('homework_table.xlsx', '4-3', index_col= 0 , na_values=['NA'], skiprows = 5, header = 0)
mess_table
# Out:
#                                                                 Unnamed: 1  \
# Země                      Studují či se jinak připravují na výkon povolání
# NaN                                               In education or training
# NaN                                                    15 - 24 let / years
# NaN                                                                   ženy
# NaN                                                                  Women
# EU 28                                                                  NaN
# Eurozóna 19                                                            NaN
# v tom:                                                                 NaN
# Belgie                                                                 NaN
# Bulharsko                                                              NaN
# Česká republika                                                        NaN
# ...

# %%
col1 = mess_table.iloc[0].fillna(method = 'ffill')
col2 = mess_table.iloc[1].str.split(pat='\n', n = 0).str.get(0)
columns = [col1, col2]

columns = list(zip(*columns))
